# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# Study data files
city_data_path = "assets/Exported City Weather Data.csv"

# Read the city data and the study results
city_metadata = pd.read_csv(city_data_path)
city_metadata = city_metadata.rename(columns={"Unnamed: 0": "City_ID"})

# %%
# Export the City Data Table for export:
city_data_html = city_metadata.to_html(index=False,header=True,col_space=20,justify='left')
city_data_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: left;">\n      <th style="min-width: 20px;">City_ID</th>\n      <th style="min-width: 20px;">Country</th>\n      <th style="min-width: 20px;">City</th>\n      <th style="min-width: 20px;">Latitude</th>\n      <th style="min-width: 20px;">Longitude</th>\n      <th style="min-width: 20px;">Current Temp(c)</th>\n      <th style="min-width: 20px;">Max Temp(c)</th>\n      <th style="min-width: 20px;">Humidity (%)</th>\n      <th style="min-width: 20px;">Cloudiness</th>\n      <th style="min-width: 20px;">Windspeed (km/h)</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>0</td>\n      <td>IT</td>\n      <td>Quartucciu</td>\n      <td>39.2519</td>\n      <td>9.1794</td>\n      <td>13.89</td>\n      <td>13.89</td>\n      <td>67</td>\n      <td>0</td>\n      <td>7.416</td>\n    </tr>\n    <tr>\n      <td>1</td>\n      <td>RO</td>\n      <td>Valea Ursului</td>\n      <td>46.8167</td>\n      <td>27.0833</td>\
# ...
